# %%
import paddle

from ppdet.modeling.backbones.efficientnet import EfficientNetB0
# from ppdet.modeling.backbones.darknet import DarkNet
# Out:
# /opt/conda/envs/paddle/lib/python3.7/site-packages/paddle/tensor/creation.py:125: DeprecationWarning: `np.object` is a deprecated alias for the builtin `object`. To silence this warning, use `object` by itself. Doing this will not modify any behavior and is safe.
# Deprecated in NumPy 1.20; for more details and guidance: https://numpy.org/devdocs/release/1.20.0-notes.html#deprecations
#   if data.dtype == np.object:
# ...

# %%
model = EfficientNetB0()
# Out:
# W0918 17:06:51.611927 104721 device_context.cc:404] Please NOTE: device: 0, GPU Compute Capability: 7.0, Driver API Version: 10.2, Runtime API Version: 10.2
# W0918 17:06:51.617144 104721 device_context.cc:422] device: 0, cuDNN Version: 7.6.

# %%
model_ = paddle.Model(model)
model_.summary((1, 3, 224, 224))
# Out:
# --------------------------------------------------------------------------------
#     Layer (type)         Input Shape          Output Shape         Param #
# ...
#       Conv2D-1        [[1, 3, 224, 224]]   [1, 32, 113, 113]         864
#      Conv2ds-1        [[1, 3, 224, 224]]   [1, 32, 112, 112]          0
#     BatchNorm-1      [[1, 32, 112, 112]]   [1, 32, 112, 112]         128
#    ConvBNLayer-1      [[1, 3, 224, 224]]   [1, 32, 112, 112]          0
#    ConvStemNorm-1     [[1, 3, 224, 224]]   [1, 32, 112, 112]          0
#       Conv2D-2       [[1, 32, 112, 112]]   [1, 32, 112, 112]         288
#      Conv2ds-2       [[1, 32, 112, 112]]   [1, 32, 112, 112]          0
#     BatchNorm-2      [[1, 32, 112, 112]]   [1, 32, 112, 112]         128
#    ConvBNLayer-2     [[1, 32, 112, 112]]   [1, 32, 112, 112]          0
# DepthwiseConvNorm-1  [[1, 32, 112, 112]]   [1, 32, 112, 112]          0
# AdaptiveAvgPool2D-1  [[1, 32, 112, 112]]     [1, 32, 1, 1]            0
# ...

# %%
input = paddle.randn(shape=(1, 3, 224, 224))
output = model(input)
output.shape
# Out:
# [1, 1000]
